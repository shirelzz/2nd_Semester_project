# %% [markdown]
# ## Cats vs Dogs

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from IPython.display import Image
from PIL import Image
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/dq/qdd4tr0j5v1ctgxtptm2v5_h0000gn/T/ipykernel_17859/3372124555.py in <module>
#       4 from IPython.display import Image
#       5 from PIL import Image
# ----> 6 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
img1 = mpimg.imread("data/12479.jpg")
img1S = cv2.resize(img1, (28, 28))
plt.imshow(img1S)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/dq/qdd4tr0j5v1ctgxtptm2v5_h0000gn/T/ipykernel_17859/3706640806.py in <module>
#       1 img1 = mpimg.imread("data/12479.jpg")
# ----> 2 img1.resize(img1, (28,28))
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
plt.imshow(img1)

# %%
plt.imshow(img1[:,:,1], cmap='gray', vmin = 0, vmax = 255,interpolation='none')

# %%
def resize(img):

# %%
def rgbToGray(img):
    R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]
    imgGray = 0.2989 * R + 0.5870 * G + 0.1140 * B
    return imgGray

# %%
plt.imshow(rgbToGray(img1), cmap='gray')

# %%
for cat_img in cat_images:

# %%
# img = img.resize((160, 240), Image.ANTIALIAS)
# img.size

# %%
# import cv2

# originalImage = cv2.imread("PATH/TO/IMG")
# grayImage = cv2.cvtColor(originalImage, cv2.COLOR_BGR2GRAY)

# %%
from IPython.display import JSON, HTML
display(JSON({'name': 'NAME', 'age': 23}))
display(HTML("<h1>Header</h1><h3>Footer</h3>"))
